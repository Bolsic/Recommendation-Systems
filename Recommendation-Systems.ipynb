# %% [markdown]
# # Učitavanje podataka i biblioteka

# %%
import pandas as pd
import seaborn as sns
import math
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

from scipy.stats.stats import pearsonr
from scipy import spatial

from IPython.display import Image

# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.7/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.21.5)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.1.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-surprise) (1.4.1)

# %%
from surprise import SVD, Reader, accuracy
from surprise import Dataset
from surprise.model_selection import cross_validate

from surprise.model_selection import train_test_split

from collections import defaultdict

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dm = pd.read_csv('drive/MyDrive/SAIS/PROJEKAT/ml-latest-small/movies.csv')

# %%
dr = pd.read_csv('drive/MyDrive/SAIS/PROJEKAT/ml-latest-small/ratings.csv')

# %% [markdown]
# # Data wrangling

# %%
#Pretvaramo 'genres' atribut u niz stringova
dm['genres'] = dm['genres'].apply(lambda x: x.split('|'))

#Dodajemo poseban atribut za svaki zanr, koji ce imati vrednost 0 ili 1
genres_flat_list = list(set([item for sublist in dm['genres'] for item in sublist]))
for item in genres_flat_list:
  dm['' + str(item)] = 0

#Postavljamo vrednosti tih atributa adekvatno
for i in range(len(dm['genres'])):
  for genre in dm['genres'][i]:
    dm['' + str(genre)][i] = 1

#Uklanjamo genres atribut
dm.drop(axis=1, columns=['genres'], inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
print('Number of ratings: ', dr.shape[0])
print('Number of users: ', len(dr['userId'].unique()))
print('Number of movies: ', dm.shape[0])
# Out:
# Number of ratings:  100836
# Number of users:  610
# Number of movies:  9742

# %%
NUM_OF_MOVIES = dm.shape[0]
NUM_OF_USERS = len(dr['userId'].unique())

# %%
# Uklanjamo rejtinge koji se odnose na filmove koji nisu u bazi
dr = dr[dr['movieId'] < NUM_OF_MOVIES]

# %% [markdown]
# # Content Based

# %% [markdown]
# Weighted Rating (WR) = $(\frac{v}{v+m}R) + (\frac{m}{v+m}C)$

# %% [markdown]
# Gde je:
#
#
# *   m - treshold minimalno dozvoljenih rejtinga za jedan film
# *   C - srednja vrednost svih rejtinga
# *   v - broj rejtinga tog filma
# *   R - srednja vrednost rejtinga tog filma

# %%
mrc = [] #Movie Rating Count (MRC)

for i in range(dm.shape[0]):
  mrc.append(0)

for i in dr['movieId']:
  if i <= len(mrc):
    mrc[i - 1] += 1

# %%
MIN_REVIEW = int(sum(mrc)/len(mrc))

m = MIN_REVIEW

C = dr['rating'].mean()

# %%
def weighted_rating(x, m=m, C=C):
    v = len(dr[dr['movieId'] == x])
    R = dr[dr['movieId'] == x]['rating'].mean()

    WR = (v / (m + v)) * R + (m / (m + v)) * C
    return WR

# %%
def CB_suggest(genre_list):
    dmr = dm.copy()
    dmr = dmr[dmr[genre_list].sum(axis=1) == len(genre_list)]

    dmr = dmr[['movieId', 'title'] + genre_list]
    
    dmr['rating'] = dmr['movieId'].apply(lambda x: weighted_rating(x))
    dmr['count'] = dmr['movieId'].apply(lambda x: dr[dr['movieId'] == x]['rating'].count()) 
    
    suggestion = dmr[dmr['count'] > MIN_REVIEW].sort_values('rating', ascending=False)

    return suggestion

# %%
genre_list = [x for x in input().split()]

suggestion = CB_suggest(genre_list)

suggestion.head()
# Out:
# Comedy Drama Romance
# ['Comedy', 'Drama', 'Romance']
#       movieId                                       title  Comedy  Drama  \
# 314       356                         Forrest Gump (1994)       1      1
# 680       898              Philadelphia Story, The (1940)       1      1
# 935      1235                     Harold and Maude (1971)       1      1
# 1730     2324  Life Is Beautiful (La Vita è bella) (1997)       1      1
# 946      1247                        Graduate, The (1967)       1      1
#
#       Romance    rating  count
# 314         1  4.148444    329
# 680         1  4.135825     29
# 935         1  4.103691     26
# 1730        1  4.094016     88
# 946         1  4.011787     79

# %% [markdown]
# # Collaborative Filtering

# %%
# Formiranje i popunjavanje rating matrice
rating_matrix = pd.DataFrame(index=dr['userId'].unique(), columns=dr['movieId'].unique())
rating_matrix[:] = 0

for item in dr.itertuples():
    rating_matrix.loc[item[1], item[2]] = item[3]

# %%
def CF_suggest(USER_ID):
  sim = []
  for i in range(len(rating_matrix)):
    sim.append(1 - spatial.distance.cosine(rating_matrix.iloc[USER_ID - 1, :], rating_matrix.iloc[i, :]))

  df_sim = pd.Series(sim, index=rating_matrix.index)
  df_sim = df_sim.sort_values(ascending=False)

  top_sim_user = df_sim.index[1]

  cf_sim = rating_matrix.loc[[top_sim_user,USER_ID]].T
  cf_sim.columns = ['top_sim_user','user']

  top_sim_user_avg = cf_sim[cf_sim['top_sim_user'] > 0]['top_sim_user'].mean()
  cf_sim['recommend'] = (cf_sim['top_sim_user'] > top_sim_user_avg) & (cf_sim['user'] == 0)   

  cf_sim[cf_sim['recommend'] == True].sort_values('top_sim_user', ascending=False)

  recommended_movies = list(cf_sim[cf_sim['recommend']].sort_values('top_sim_user', ascending = False).index)

  result = dm[dm['movieId'].isin(recommended_movies)].copy()
  result['rating'] = dr[(dr['movieId'].isin(recommended_movies)) & (dr['userId'] == top_sim_user)]['rating'].values

  result = result.sort_values('rating', ascending = False)

  return result

# %%
USER_ID = int(input())
cf_suggestion = CF_suggest(USER_ID)

cf_suggestion.head()
# Out:
# 19
#       movieId                      title  (no genres listed)  Mystery  Drama  \
# 2410     3200    Last Detail, The (1973)                   0        0      1
# 520       608               Fargo (1996)                   0        0      1
# 1232     1641     Full Monty, The (1997)                   0        0      1
# 2543     3404             Titanic (1953)                   0        0      1
# 742       969  African Queen, The (1951)                   0        0      0
#
#       Comedy  Musical  Romance  Fantasy  Documentary  ...  Children  Crime  \
# 2410       1        0        0        0            0  ...         0      0
# 520        1        0        0        0            0  ...         0      1
# 1232       1        0        0        0            0  ...         0      0
# 2543       0        0        0        0            0  ...         0      0
# 742        1        0        1        0            0  ...         0      0
#
#       War  IMAX  Action  Adventure  Film-Noir  Thriller  Sci-Fi  rating
# 2410    0     0       0          0          0         0       0     5.0
# 520     0     0       0          0          0         1       0     5.0
# 1232    0     0       0          0          0         0       0     5.0
# 2543    0     0       1          0          0         0       0     5.0
# 742     1     0       0          1          0         0       0     4.0
#
# [5 rows x 23 columns]

# %% [markdown]
# # Postava za korišćenje modela

# %%
reader = Reader()
data = Dataset.load_from_df(dr[['userId', 'movieId', 'rating']], reader)

# Odvajanje baze na teo za treniranje i deo za testiranje
train_set, test_set = train_test_split(data, test_size=.25)

# %%
def MODEL_suggest(model, USER_ID):
  predictions = model.test(test_set)
  a = []
  for i in range(NUM_OF_MOVIES):
    a.append(model.predict(19, i))

  npa = np.array(a)
  npa = npa[npa[:, 3].argsort()]

  new_dm = dm[dm['movieId'].isin(npa[:, 1][-10:])].copy()  

  return new_dm

# %%
def MODEL_suggest_wo_table(model, test_set):
  predictions = model.test(test_set)
  return predictions

# %% [markdown]
# # SVD model

# %%
from surprise import SVD

# %%
model_SVD = SVD() #metoda je tako napravljena da se moze staviti bilo koji model

# %%
# %%time

# Treniranje modela
model_SVD.fit(train_set)
# Out:
# CPU times: user 3.63 s, sys: 7.28 ms, total: 3.64 s
# Wall time: 3.66 s

# %%
test = MODEL_suggest(model_SVD, USER_ID)

# %%
test
# Out:
#       movieId                                              title  \
# 685       903                                     Vertigo (1958)
# 704       922      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
# 898      1196  Star Wars: Episode V - The Empire Strikes Back...
# 899      1197                         Princess Bride, The (1987)
# 900      1198  Raiders of the Lost Ark (Indiana Jones and the...
# 901      1199                                      Brazil (1985)
# 906      1204                          Lawrence of Arabia (1962)
# 1939     2571                                 Matrix, The (1999)
# 2195     2918                    Ferris Bueller's Day Off (1986)
# 2462     3275                        Boondock Saints, The (2000)
#
#       (no genres listed)  Mystery  Drama  Comedy  Musical  Romance  Fantasy  \
# 685                    0        1      1       0        0        1        0
# 704                    0        0      1       0        0        1        0
# 898                    0        0      0       0        0        0        0
# 899                    0        0      0       1        0        1        1
# 900                    0        0      0       0        0        0        0
# 901                    0        0      0       0        0        0        1
# 906                    0        0      1       0        0        0        0
# 1939                   0        0      0       0        0        0        0
# 2195                   0        0      0       1        0        0        0
# 2462                   0        0      1       0        0        0        0
#
#       Documentary  ...  Animation  Children  Crime  War  IMAX  Action  \
# 685             0  ...          0         0      0    0     0       0
# 704             0  ...          0         0      0    0     0       0
# 898             0  ...          0         0      0    0     0       1
# 899             0  ...          0         0      0    0     0       1
# 900             0  ...          0         0      0    0     0       1
# 901             0  ...          0         0      0    0     0       0
# 906             0  ...          0         0      0    1     0       0
# 1939            0  ...          0         0      0    0     0       1
# 2195            0  ...          0         0      0    0     0       0
# 2462            0  ...          0         0      1    0     0       1
#
#       Adventure  Film-Noir  Thriller  Sci-Fi
# 685           0          0         1       0
# 704           0          1         0       0
# 898           1          0         0       1
# 899           1          0         0       0
# 900           1          0         0       0
# 901           0          0         0       1
# 906           1          0         0       0
# 1939          0          0         1       1
# 2195          0          0         0       0
# 2462          0          0         1       0
#
# [10 rows x 22 columns]

# %% [markdown]
# # Normal Predictor model

# %%
from surprise import NormalPredictor

# %%
model_NP = NormalPredictor()

# %%
# %%time

model_NP.fit(train_set)
# Out:
# CPU times: user 79.2 ms, sys: 828 µs, total: 80.1 ms
# Wall time: 85.6 ms

# %%
test_NP = MODEL_suggest(model_NP, USER_ID)

# %%
test
# Out:
#       movieId                                              title  \
# 602       750  Dr. Strangelove or: How I Learned to Stop Worr...
# 685       903                                     Vertigo (1958)
# 686       904                                 Rear Window (1954)
# 899      1197                         Princess Bride, The (1987)
# 943      1244                                   Manhattan (1979)
# 990      1291          Indiana Jones and the Last Crusade (1989)
# 1057     1374             Star Trek II: The Wrath of Khan (1982)
# 2226     2959                                  Fight Club (1999)
# 4137     5952      Lord of the Rings: The Two Towers, The (2002)
# 4360     6377                                Finding Nemo (2003)
#
#       (no genres listed)  Mystery  Drama  Comedy  Musical  Romance  Fantasy  \
# 602                    0        0      0       1        0        0        0
# 685                    0        1      1       0        0        1        0
# 686                    0        1      0       0        0        0        0
# 899                    0        0      0       1        0        1        1
# 943                    0        0      1       1        0        1        0
# 990                    0        0      0       0        0        0        0
# 1057                   0        0      0       0        0        0        0
# 2226                   0        0      1       0        0        0        0
# 4137                   0        0      0       0        0        0        1
# 4360                   0        0      0       1        0        0        0
#
#       Documentary  ...  Animation  Children  Crime  War  IMAX  Action  \
# 602             0  ...          0         0      0    1     0       0
# 685             0  ...          0         0      0    0     0       0
# 686             0  ...          0         0      0    0     0       0
# 899             0  ...          0         0      0    0     0       1
# 943             0  ...          0         0      0    0     0       0
# 990             0  ...          0         0      0    0     0       1
# 1057            0  ...          0         0      0    0     0       1
# 2226            0  ...          0         0      1    0     0       1
# 4137            0  ...          0         0      0    0     0       0
# 4360            0  ...          1         1      0    0     0       0
#
#       Adventure  Film-Noir  Thriller  Sci-Fi
# 602           0          0         0       0
# 685           0          0         1       0
# 686           0          0         1       0
# 899           1          0         0       0
# 943           0          0         0       0
# 990           1          0         0       0
# 1057          1          0         1       1
# 2226          0          0         1       0
# 4137          1          0         0       0
# 4360          1          0         0       0
#
# [10 rows x 22 columns]

# %% [markdown]
# # kNN model

# %%
from surprise import KNNBasic

# %%
model_KNN = KNNBasic()

# %%
model_KNN.fit(train_set)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
test_KNN = MODEL_suggest(model_KNN, USER_ID)

# %%
test_KNN
# Out:
#       movieId                                              title  \
# 531       626          Thin Line Between Love and Hate, A (1996)
# 536       633                             Denise Calls Up (1995)
# 666       876     Supercop 2 (Project S) (Chao ji ji hua) (1993)
# 865      1140  Entertaining Angels: The Dorothy Day Story (1996)
# 870      1151                                Lesson Faust (1994)
# 1746     2342                              Hard Core Logo (1996)
# 2597     3473  Jonah Who Will Be 25 in the Year 2000 (Jonas q...
# 2611     3496                            Madame Sousatzka (1988)
# 3031     4055                                       Panic (2000)
# 3908     5490                                 The Big Bus (1976)
#
#       (no genres listed)  Mystery  Drama  Comedy  Musical  Romance  Fantasy  \
# 531                    0        0      0       1        0        0        0
# 536                    0        0      0       1        0        0        0
# 666                    0        0      0       1        0        0        0
# 865                    0        0      1       0        0        0        0
# 870                    0        0      1       1        0        0        1
# 1746                   0        0      1       1        0        0        0
# 2597                   0        0      0       1        0        0        0
# 2611                   0        0      1       0        0        0        0
# 3031                   0        0      1       0        0        0        0
# 3908                   0        0      0       1        0        0        0
#
#       Documentary  ...  Animation  Children  Crime  War  IMAX  Action  \
# 531             0  ...          0         0      0    0     0       0
# 536             0  ...          0         0      0    0     0       0
# 666             0  ...          0         0      1    0     0       1
# 865             0  ...          0         0      0    0     0       0
# 870             0  ...          1         0      0    0     0       0
# 1746            0  ...          0         0      0    0     0       0
# 2597            0  ...          0         0      0    0     0       0
# 2611            0  ...          0         0      0    0     0       0
# 3031            0  ...          0         0      0    0     0       0
# 3908            0  ...          0         0      0    0     0       1
#
#       Adventure  Film-Noir  Thriller  Sci-Fi
# 531           0          0         0       0
# 536           0          0         0       0
# 666           0          0         1       0
# 865           0          0         0       0
# 870           0          0         0       0
# 1746          0          0         0       0
# 2597          0          0         0       0
# 2611          0          0         0       0
# 3031          0          0         0       0
# 3908          0          0         0       0
#
# [10 rows x 22 columns]

# %% [markdown]
# # Testiranje vremena

# %%
genres_flat_list
# Out:
# ['(no genres listed)',
#  'Mystery',
#  'Drama',
#  'Comedy',
#  'Musical',
#  'Romance',
#  'Fantasy',
#  'Documentary',
#  'Western',
#  'Horror',
#  'Animation',
#  'Children',
#  'Crime',
#  'War',
#  'IMAX',
#  'Action',
#  'Adventure',
#  'Film-Noir',
#  'Thriller',
#  'Sci-Fi']

# %%
from itertools import combinations

# %%
for combo in combinations(['aa', 'bb', 'cc', 'dd'], 2):
    print(list(combo))
# Out:
# ['aa', 'bb']
# ['aa', 'cc']
# ['aa', 'dd']
# ['bb', 'cc']
# ['bb', 'dd']
# ['cc', 'dd']

# %%
len(genres_flat_list)
# Out:
# 20

# %%
new_genres_flat_list = genres_flat_list[1:]

# %%
new_genres_flat_list[0]
# Out:
# 'Mystery'

# %%
# %%time
# n_CB = 0
# for i in range(len(new_genres_flat_list)):
#   for combo in combinations(new_genres_flat_list, i):
#     CB_suggest(list(combo))
#     n_CB += 1
#     print(n_CB)


# print("FINISHED", n_CB)

# %%
# %%time
CB_suggest(['Drama', 'Romance', 'Comedy'])
# Out:
# CPU times: user 592 ms, sys: 3.7 ms, total: 596 ms
# Wall time: 598 ms
#       movieId                                       title  Drama  Romance  \
# 314       356                         Forrest Gump (1994)      1        1
# 680       898              Philadelphia Story, The (1940)      1        1
# 935      1235                     Harold and Maude (1971)      1        1
# 1730     2324  Life Is Beautiful (La Vita è bella) (1997)      1        1
# 946      1247                        Graduate, The (1967)      1        1
# ...       ...                                         ...    ...      ...
# 475       542                           Son in Law (1993)      1        1
# 330       372                        Reality Bites (1994)      1        1
# 2859     3825                          Coyote Ugly (2000)      1        1
# 1771     2369            Desperately Seeking Susan (1985)      1        1
# 1085     1409                              Michael (1996)      1        1
#
#       Comedy    rating  count
# 314        1  4.148444    329
# 680        1  4.135825     29
# 935        1  4.103691     26
# 1730       1  4.094016     88
# 946        1  4.011787     79
# ...      ...       ...    ...
# 475        1  3.046614     14
# 330        1  2.966397     21
# 2859       1  2.906095     29
# 1771       1  2.875797     24
# 1085       1  2.758887     23
#
# [85 rows x 7 columns]

# %%
NUM_OF_USERS

# %%
# %%time
n = 0
for user in range(1, NUM_OF_USERS):
  CF_suggest(user)
  n += 1
  print(n)

# %%
AVG_CF_TIME = (14 * 60) / NUM_OF_USERS
print("Average time for CF method:", AVG_CF_TIME, "s")
# Out:
# Average time for CF method: 1.3770491803278688 s

# %%
# %%time 

for i in range(100):
  prediction_SVD = MODEL_suggest_wo_table(model_SVD, test_set)
# Out:
# CPU times: user 25.8 s, sys: 686 ms, total: 26.5 s
# Wall time: 30 s

# %%
AVG_SVD_TIME = 30 / 100
print("Average time for SVD model:", AVG_SVD_TIME, "s")
# Out:
# Average time for SVD model: 0.3 s

# %%
# %%time 
for i in range(100):
  prediction_NP = MODEL_suggest_wo_table(model_NP, test_set)
# Out:
# CPU times: user 23.4 s, sys: 197 ms, total: 23.6 s
# Wall time: 25.1 s

# %%
AVG_NP_TIME = 25 / 100
print("Average time for SVD model:", AVG_NP_TIME, "s")
# Out:
# Average time for SVD model: 0.25 s

# %%
# %%time 
for i in range(100):
  prediction_KNN = MODEL_suggest_wo_table(model_KNN, test_set)
# Out:
# CPU times: user 2min 50s, sys: 374 ms, total: 2min 51s
# Wall time: 2min 57s

# %%
AVG_KNN_TIME = (3 * 60) / 100
print("Average time for SVD model:", AVG_KNN_TIME, "s")
# Out:
# Average time for SVD model: 1.8 s
